# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Garima\\Desktop\\DATA SCIENCE\\python'

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
train.shape
# Out:
# (8523, 12)

# %%
test.shape
# Out:
# (5681, 11)

# %%
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
##Consolidating data for EDA
np.min(train['Item_Outlet_Sales'])
np.max(train['Item_Outlet_Sales'])

bmart=train.append(test)

# %%
bmart.shape
# Out:
# (14204, 12)

# %%
bmart.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
bmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14204 entries, 0 to 5680
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
bmart['Item_Outlet_Sales'].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 1845.5976    15
# 703.0848     15
# 1278.3360    14
#              ..
# 3167.8764     1
# 2226.4352     1
# 1684.4740     1
# 1574.6170     1
# 6692.6216     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
bmart.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
bmart.nunique()
# Out:
# Item_Identifier               1559
# Item_Weight                    415
# Item_Fat_Content                 5
# Item_Visibility              13006
# Item_Type                       16
# Item_MRP                      8052
# Outlet_Identifier               10
# Outlet_Establishment_Year        9
# Outlet_Size                      3
# Outlet_Location_Type             3
# Outlet_Type                      4
# Item_Outlet_Sales             3493
# dtype: int64

# %% [markdown]
# #### EDA

# %% [markdown]
# #### univariate analysis

# %%
bmart['Item_Fat_Content'] = bmart['Item_Fat_Content'].replace(['LF','Low fat'],'Low Fat')

# %%
bmart['Item_Fat_Content'] = bmart['Item_Fat_Content'].replace(['reg'],'Regular')

# %%
bmart['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    9007
# Regular    5019
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
bmart['Item_Fat_Content'].value_counts(normalize=True)*100
# Out:
# Low Fat    63.411715
# Regular    35.335117
# low fat     1.253168
# Name: Item_Fat_Content, dtype: float64

# %%
# bmart['Item_Outlet_Sales'].fillna(bmart.groupby(['Outlet_Type','Outlet_Location_Type'])['Item_Outlet_Sales'].transform('max'),inplace=True)

# %%
bmart.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
sns.distplot(bmart['Item_MRP'])
# Out:
# C:\Users\Garima\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.heatmap(bmart.corr())
# Out:
# <AxesSubplot:>

# %%
# Categorical column
bmart.select_dtypes(include= 'object').columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
bmart.select_dtypes(include= [np.number]).columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sns.boxplot(bmart['Item_MRP'])
# Out:
# C:\Users\Garima\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.boxplot(bmart['Item_Visibility'])
# Out:
# C:\Users\Garima\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
sns.boxplot(bmart['Outlet_Establishment_Year'])
# Out:
# C:\Users\Garima\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
bmart['Item_Weight']=bmart['Item_Weight'].fillna(bmart['Item_Weight'].groupby(bmart['Item_Type']).transform('mean'))

# %%
bmart.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
bmart['Outlet_Size']=bmart['Outlet_Size'].fillna("Small")

# %%
bmart.select_dtypes("object").head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# 1      Medium               Tier 3  Supermarket Type2
# 2      Medium               Tier 1  Supermarket Type1
# 3       Small               Tier 3      Grocery Store
# 4        High               Tier 3  Supermarket Type1

# %%
# bmart[(bmart.Outlet_Location_Type=="Tier 2") & (bmart.Outlet_Type=="Supermarket Type1")]['Outlet_Size'].fillna("Small",inplace=True)

# %%
bmart.tail(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 5679           FDJ26         15.3          Regular          0.00000    Canned
# 5680           FDU37          9.5          Regular          0.10472    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 5679  214.6218            OUT017                       2007       Small
# 5680   79.7960            OUT045                       2002       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 5679               Tier 2  Supermarket Type1                NaN
# 5680               Tier 2  Supermarket Type1                NaN

# %%
bmart.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
bmart1=bmart.copy()

# %%
bmart2=bmart1.copy()
bmart2['Outlet_Size'].fillna("ZZZ",inplace=True)
pd.crosstab([bmart2.Outlet_Type,bmart2.Outlet_Location_Type],bmart2.Outlet_Size)
# Out:
# Outlet_Size                             High  Medium  Small
# Outlet_Type       Outlet_Location_Type
# Grocery Store     Tier 1                   0       0    880
#                   Tier 3                   0       0    925
# Supermarket Type1 Tier 1                   0    1550   1550
#                   Tier 2                   0       0   4641
#                   Tier 3                1553       0      0
# Supermarket Type2 Tier 3                   0    1546      0
# Supermarket Type3 Tier 3                   0    1559      0

# %%
bmart1.shape
# Out:
# (14204, 12)

# %%
bmart1["Outlet_Size"].isnull().sum()
# Out:
# 0

# %%
bmart1["Outlet_Size"].value_counts().isnull()
# Out:
# Small     False
# Medium    False
# High      False
# Name: Outlet_Size, dtype: bool

# %%
# bmart1[(bmart1.Outlet_Location_Type=="Tier 2") & (bmart1.Outlet_Type=="Supermarket Type1")]['Outlet_Size'].fillna("Small",inplace=True)

# %%
print(np.min(range(bmart1.shape[0])))
print(np.max(range(bmart1.shape[0])))
# Out:
# 0
# 14203

# %%
# bmart.shape()

# %%
bmart1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
bmart1.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
bmart.shape
# Out:
# (14204, 12)

# %%
bmart1['Outlet_Size']=bmart1['Outlet_Size'].fillna("Small")

# %%
bmart1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
# bmart.info()

# %%
bgm = pd.get_dummies(bmart1,drop_first=True)

# %%
train_cl=bgm[bgm['Item_Outlet_Sales'].notnull()]
test_cl=bgm[bgm['Item_Outlet_Sales'].isnull()]

# %%
print(train_cl.shape)
print(test_cl.shape)
# Out:
# (8523, 1596)
# (5681, 1596)

# %%
train_cl.head(2)
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
#
#    Item_Outlet_Sales  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0          3735.1380                      0                      0
# 1           443.4228                      0                      0
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  ...  \
# 0                      0                      0                      0  ...
# 1                      0                      0                      0  ...
#
#    Outlet_Identifier_OUT045  Outlet_Identifier_OUT046  \
# 0                         0                         0
# 1                         0                         0
#
#    Outlet_Identifier_OUT049  Outlet_Size_Medium  Outlet_Size_Small  \
# 0                         1                   1                  0
# ...

# %%
train_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8523 entries, 0 to 8522
# Columns: 1596 entries, Item_Weight to Outlet_Type_Supermarket Type3
# dtypes: float64(4), int64(1), uint8(1591)
# memory usage: 13.3 MB

# %%
test_cl.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    20.750000         0.007565  107.8622                       1999
# 1     8.300000         0.038428   87.3198                       2007
# 2    14.600000         0.099575  241.7538                       1998
# 3     7.315000         0.015388  155.0340                       2007
# 4    13.238358         0.118599  234.2300                       1985
#
#    Item_Outlet_Sales  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                NaN                      0                      0
# 1                NaN                      0                      0
# 2                NaN                      0                      0
# 3                NaN                      0                      0
# 4                NaN                      0                      0
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  ...  \
# ...

# %%
test_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5681 entries, 0 to 5680
# Columns: 1596 entries, Item_Weight to Outlet_Type_Supermarket Type3
# dtypes: float64(4), int64(1), uint8(1591)
# memory usage: 8.9 MB

# %%
train_cl.isnull().sum()
# Out:
# Item_Weight                      0
# Item_Visibility                  0
# Item_MRP                         0
# Outlet_Establishment_Year        0
# Item_Outlet_Sales                0
#                                 ..
# Outlet_Location_Type_Tier 2      0
# Outlet_Location_Type_Tier 3      0
# Outlet_Type_Supermarket Type1    0
# Outlet_Type_Supermarket Type2    0
# Outlet_Type_Supermarket Type3    0
# Length: 1596, dtype: int64

# %%
print(train_cl.shape)
print(test_cl.shape)
# Out:
# (8523, 1596)
# (5681, 1596)

# %%
test_cl.drop('Item_Outlet_Sales',axis=1,inplace=True)
# Out:
# C:\Users\Garima\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test_cl.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    20.750000         0.007565  107.8622                       1999
# 1     8.300000         0.038428   87.3198                       2007
# 2    14.600000         0.099575  241.7538                       1998
# 3     7.315000         0.015388  155.0340                       2007
# 4    13.238358         0.118599  234.2300                       1985
#
#    Item_Identifier_DRA24  Item_Identifier_DRA59  Item_Identifier_DRB01  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      0                      0                      0
#
#    Item_Identifier_DRB13  Item_Identifier_DRB24  Item_Identifier_DRB25  ...  \
# ...

# %% [markdown]
# ## Prepare Dummies

# %%
# train_cl=pd.get_dummies(train_cl,drop_first=True)
# test_cl=pd.get_dummies(test_cl,drop_first=True)

# %%
# print(train_cl.shape)
# print(test_cl.shape)

# %%
# train_cl.head()

# %%
# train_cl.describe()

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
train_Y=train_cl['Item_Outlet_Sales']
train_X=train_cl.drop('Item_Outlet_Sales',axis=1)

# %%
train_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8523 entries, 0 to 8522
# Columns: 1595 entries, Item_Weight to Outlet_Type_Supermarket Type3
# dtypes: float64(3), int64(1), uint8(1591)
# memory usage: 13.3 MB

# %%
train_Y.head()
# Out:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
# from sklearn.model_selection import train_test_split

# %%
# X_train,X_test,Y_train,Y_test=train_test_split(train_X,train_Y,train_size=0.7,random_state=100)

# %%
# print("X Train",X_train.shape)
# print("X Test",X_test.shape)
# print("Y Train",Y_train.shape)
# print("Y Test",Y_test.shape)

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(train_X,train_Y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 2786318523510.8506

# %%
df_coef=pd.DataFrame(lm.coef_,train_X.columns,columns=['Coef'])
df_coef
# Out:
#                                        Coef
# Item_Weight                   -1.443441e+00
# Item_Visibility               -3.753212e+02
# Item_MRP                      -9.458846e-02
# Outlet_Establishment_Year     -5.499152e+08
# Item_Identifier_DRA24         -1.094034e+12
# ...                                     ...
# Outlet_Location_Type_Tier 2    1.035800e+12
# Outlet_Location_Type_Tier 3   -4.915308e+11
# Outlet_Type_Supermarket Type1 -2.941502e+11
# Outlet_Type_Supermarket Type2 -1.178863e+13
# Outlet_Type_Supermarket Type3 -1.867531e+12
#
# [1595 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ## Prediction

# %%
Y_Pred=lm.predict(test_cl)

# %%
Y_Pred
# Out:
# array([1686.05615234, 1609.91699219, 2523.53613281, ..., 2048.44921875,
#        2672.29589844, 1759.18164062])

# %%
Y_Pred.shape
# Out:
# (5681,)

# %%
test.shape
# Out:
# (5681, 11)

# %%
import statsmodels.api as sm

# %%
# X_train_1=X_train.copy()

# %%
# X_train_1

# %%
# X_train_1=sm.add_constant(X_train_1)

# %%
#OLS ordinary least ssquare
lm1=sm.OLS(train_Y,train_X).fit()
lm1.params
#parameters
# Out:
# Item_Weight                        -1.443654
# Item_Visibility                  -375.288217
# Item_MRP                           -0.094588
# Outlet_Establishment_Year           0.680113
# Item_Identifier_DRA24             338.889507
#                                     ...
# Outlet_Location_Type_Tier 2       558.289239
# Outlet_Location_Type_Tier 3      -347.361028
# Outlet_Type_Supermarket Type1     899.247494
# Outlet_Type_Supermarket Type2     137.601902
# Outlet_Type_Supermarket Type3    1007.869827
# Length: 1595, dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Item_Outlet_Sales   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     7.981
# Date:                Sat, 01 May 2021   Prob (F-statistic):               0.00
# Time:                        23:17:40   Log-Likelihood:                -71130.
# No. Observations:                8523   AIC:                         1.454e+05
# Df Residuals:                    6951   BIC:                         1.565e+05
# Df Model:                        1571
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
c=[i for i in range(1,150,1)]
fig=plt.figure()
plt.plot(c,train_Y[1:150],color="blue",linestyle="-")
plt.plot(c,Y_Pred[1:150],color="red",linestyle="-")

# %%
test_submit=test[['Item_Identifier','Outlet_Identifier']]

# %%
test.shape
# Out:
# (5681, 11)

# %%
Y_Pred.shape
# Out:
# (5681,)

# %%
pred_data=pd.concat([test_submit,pd.DataFrame(Y_Pred)],axis=1)

# %%
pred_data.tail(2)
# Out:
#      Item_Identifier Outlet_Identifier            0
# 5679           FDJ26            OUT017  2672.295898
# 5680           FDU37            OUT045  1759.181641

# %%
pred_data.to_csv("bgs2.csv",index=False)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Garima\\Desktop\\DATA SCIENCE\\python'
